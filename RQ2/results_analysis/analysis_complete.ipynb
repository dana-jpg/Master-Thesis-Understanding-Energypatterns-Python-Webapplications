# %%
# statistical analysis across all metrics (DRAM, package, overall), measurment granularities (system, process) and experiments (except for compression)
from pathlib import Path
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from matplotlib.ticker import ScalarFormatter


DATA_DIR = Path("../data/experiment_results_raw")


METRICS = {
    "Process energy per run": "proc_energy_per_run_J",
    "Process energy per run — Package": "pkg_energy_per_run_J",
    "Process energy per run — DRAM": "dram_energy_per_run_J",
    "System energy per run (net)": "net_sys_host_per_run_J",
    "System energy per run (net) — Package": "net_sys_pkg_per_run_J",
    "System energy per run (net) — DRAM": "net_sys_dram_per_run_J",
}


def mean_ci(x, alpha=0.05):
    x = np.asarray(x)
    m = x.mean()
    h = stats.sem(x) * stats.t.ppf(1 - alpha/2, len(x)-1)
    return m, m - h, m + h

def cliffs_delta(x, y):
    gt = sum(i > j for i in x for j in y)
    lt = sum(i < j for i in x for j in y)
    delta = (gt - lt) / (len(x) * len(y))
    mag = (
        "negligible" if abs(delta) < 0.147 else
        "small" if abs(delta) < 0.33 else
        "medium" if abs(delta) < 0.474 else
        "large"
    )
    return delta, mag

def remove_outliers(x, lower_q=0.005, upper_q=0.995):
    lo, hi = np.quantile(x, [lower_q, upper_q])
    return x[(x >= lo) & (x <= hi)]

def format_p(p, threshold=1e-6):
    if p < threshold:
        return f"{p:.2e}"
    else:
        return f"{p:.6f}"


experiments = {}
for f in DATA_DIR.glob("energy_results_*.json"):
    stem = f.stem.replace("energy_results_", "")
    op, suffix = stem.rsplit("_", 1)
    experiments.setdefault(op, {})[suffix] = f


for operation, files in experiments.items():

    if len(files) != 2:
        continue

    print("\n" + "="*60)
    print(f"Operation: {operation}")
    print("="*60)

    # Load data
    frames = []

    for suffix, path in files.items():
        with open(path) as f:
            trials = json.load(f)["trials"]

        df = pd.DataFrame(trials)
        df["variant"] = suffix
        frames.append(df)

    df = pd.concat(frames, ignore_index=True)

    # Convert J → mJ
    for c in df.columns:
        if c.endswith("_J"):
            df[c.replace("_J", "_mJ")] = df[c] * 1000

    variants = df["variant"].unique().tolist()

    v_unopt = next(v for v in variants if "unoptimized" in v.lower())
    v_opt   = next(v for v in variants if "optimized" in v.lower() and "unoptimized" not in v.lower())


    for label, base_col in METRICS.items():

        col = base_col.replace("_J", "_mJ")

        x = df[df["variant"] == v_unopt][col].dropna().to_numpy()
        y = df[df["variant"] == v_opt][col].dropna().to_numpy()

        x = remove_outliers(x)
        y = remove_outliers(y)


        fig, ax = plt.subplots(figsize=(5,4))

        ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)

        ax.set_title(f"{operation} — {label}")
        ax.set_ylabel("Energy per run (mJ)")
        ax.set_ylim(bottom=0)

        ax.grid(axis="y", alpha=0.3)

        ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=False))
        ax.ticklabel_format(style="plain", axis="y")

        plt.tight_layout()
        plt.show()


        m1, l1, h1 = mean_ci(x)
        m2, l2, h2 = mean_ci(y)

        t, p_t = stats.ttest_ind(x, y, equal_var=False)
        u, p_u = stats.mannwhitneyu(x, y, alternative="two-sided")

        pooled = np.sqrt((x.var() + y.var()) / 2)
        d = (m1 - m2) / pooled if pooled > 0 else 0.0

        delta, mag = cliffs_delta(x, y)

        print(label)
        print(f"{v_unopt}: {m1:.3f} mJ (95% CI [{l1:.3f}, {h1:.3f}])")
        print(f"{v_opt}:   {m2:.3f} mJ (95% CI [{l2:.3f}, {h2:.3f}])")

        print(f"Welch t-test p = {format_p(p_t)}")
        print(f"Mann–Whitney U p = {format_p(p_u)}")
        print(f"Cohen's d = {d:.3f}")
        print(f"Cliff's delta = {delta:.3f} ({mag})")
        print()
# Out:
# ============================================================
# Operation: validate_billing
# ============================================================
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run
# unoptimized: 3.862 mJ (95% CI [3.846, 3.878])
# optimized:   3.030 mJ (95% CI [3.026, 3.034])
# Welch t-test p = 1.79e-27
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 35.740
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run — Package
# unoptimized: 3.597 mJ (95% CI [3.583, 3.612])
# optimized:   2.800 mJ (95% CI [2.797, 2.803])
# Welch t-test p = 9.44e-28
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 38.320
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run — DRAM
# unoptimized: 0.295 mJ (95% CI [0.294, 0.297])
# optimized:   0.230 mJ (95% CI [0.229, 0.231])
# Welch t-test p = 4.80e-36
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 31.638
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net)
# unoptimized: 15.012 mJ (95% CI [13.688, 16.335])
# optimized:   16.885 mJ (95% CI [16.110, 17.660])
# Welch t-test p = 0.015625
# Mann–Whitney U p = 0.011894
# Cohen's d = -0.884
# Cliff's delta = -0.494 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net) — Package
# unoptimized: 14.118 mJ (95% CI [12.863, 15.374])
# optimized:   16.239 mJ (95% CI [15.651, 16.827])
# Welch t-test p = 0.003580
# Mann–Whitney U p = 0.002265
# Cohen's d = -1.107
# Cliff's delta = -0.599 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net) — DRAM
# unoptimized: 1.161 mJ (95% CI [0.980, 1.342])
# optimized:   0.587 mJ (95% CI [0.333, 0.842])
# Welch t-test p = 0.000511
# Mann–Whitney U p = 0.001650
# Cohen's d = 1.300
# Cliff's delta = 0.608 (large)
#
#
# ============================================================
# Operation: reorder_item
# ============================================================
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run
# unoptimized: 314.827 mJ (95% CI [307.384, 322.270])
# optimized:   1.674 mJ (95% CI [1.626, 1.723])
# Welch t-test p = 4.08e-24
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 30.445
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run — Package
# unoptimized: 290.552 mJ (95% CI [283.707, 297.397])
# optimized:   1.543 mJ (95% CI [1.499, 1.587])
# Welch t-test p = 3.83e-24
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 30.554
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run — DRAM
# unoptimized: 24.405 mJ (95% CI [23.800, 25.009])
# optimized:   0.130 mJ (95% CI [0.126, 0.134])
# Welch t-test p = 8.98e-24
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 29.059
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net)
# unoptimized: 3.217 mJ (95% CI [-3.541, 9.974])
# optimized:   5.971 mJ (95% CI [2.712, 9.230])
# Welch t-test p = 0.447540
# Mann–Whitney U p = 0.000719
# Cohen's d = -0.257
# Cliff's delta = -0.546 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net) — Package
# unoptimized: 61.221 mJ (95% CI [12.598, 109.844])
# optimized:   5.492 mJ (95% CI [2.411, 8.573])
# Welch t-test p = 0.027157
# Mann–Whitney U p = 0.668437
# Cohen's d = 0.801
# Cliff's delta = 0.080 (negligible)
# System energy per run (net) — DRAM
# unoptimized: 0.000 mJ (95% CI [0.000, 0.000])
# optimized:   0.275 mJ (95% CI [0.067, 0.483])
# Welch t-test p = 0.012350
# Mann–Whitney U p = 0.004379
# Cohen's d = -0.927
# Cliff's delta = -0.368 (medium)
#
#
# ============================================================
# Operation: generate_report
# ============================================================
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run
# unoptimized: 99.139 mJ (95% CI [96.991, 101.286])
# optimized:   62.547 mJ (95% CI [62.352, 62.743])
# Welch t-test p = 1.17e-17
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 12.280
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run — Package
# unoptimized: 89.169 mJ (95% CI [87.128, 91.210])
# optimized:   56.130 mJ (95% CI [55.938, 56.321])
# Welch t-test p = 2.74e-17
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 11.665
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run — DRAM
# unoptimized: 7.643 mJ (95% CI [7.449, 7.837])
# optimized:   4.664 mJ (95% CI [4.643, 4.685])
# Welch t-test p = 5.83e-17
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 11.047
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net)
# unoptimized: 1145.136 mJ (95% CI [1098.800, 1191.472])
# optimized:   374.613 mJ (95% CI [360.401, 388.824])
# Welch t-test p = 3.60e-19
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 11.505
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net) — Package
# unoptimized: 1238.167 mJ (95% CI [1215.482, 1260.853])
# optimized:   480.365 mJ (95% CI [466.023, 494.706])
# Welch t-test p = 1.21e-31
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 20.433
# Cliff's delta = 1.000 (large)
# System energy per run (net) — DRAM
# unoptimized: 184.155 mJ (95% CI [164.855, 203.456])
# optimized:   67.951 mJ (95% CI [61.147, 74.755])
# Welch t-test p = 6.80e-11
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 4.109
# Cliff's delta = 1.000 (large)
#
#
# ============================================================
# Operation: bulk_import
# ============================================================
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run
# unoptimized: 60115.100 mJ (95% CI [58934.560, 61295.641])
# optimized:   58333.113 mJ (95% CI [57843.793, 58822.433])
# Welch t-test p = 0.007389
# Mann–Whitney U p = 0.009049
# Cohen's d = 1.009
# Cliff's delta = 0.512 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run — Package
# unoptimized: 55392.157 mJ (95% CI [54391.694, 56392.620])
# optimized:   53765.019 mJ (95% CI [53324.982, 54205.056])
# Welch t-test p = 0.004527
# Mann–Whitney U p = 0.005634
# Cohen's d = 1.077
# Cliff's delta = 0.543 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run — DRAM
# unoptimized: 4722.943 mJ (95% CI [4536.208, 4909.678])
# optimized:   4568.094 mJ (95% CI [4501.646, 4634.542])
# Welch t-test p = 0.114005
# Mann–Whitney U p = 0.132882
# Cohen's d = 0.565
# Cliff's delta = 0.296 (small)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net)
# unoptimized: 1241040.920 mJ (95% CI [978437.963, 1503643.877])
# optimized:   923554.334 mJ (95% CI [877051.121, 970057.546])
# Welch t-test p = 0.021734
# Mann–Whitney U p = 0.000008
# Cohen's d = 0.862
# Cliff's delta = 0.877 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net) — Package
# unoptimized: 1075457.523 mJ (95% CI [847786.725, 1303128.320])
# optimized:   818652.879 mJ (95% CI [779868.680, 857437.078])
# Welch t-test p = 0.030639
# Mann–Whitney U p = 0.000018
# Cohen's d = 0.805
# Cliff's delta = 0.840 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net) — DRAM
# unoptimized: 164773.307 mJ (95% CI [129926.897, 199619.717])
# optimized:   111143.268 mJ (95% CI [103223.902, 119062.633])
# Welch t-test p = 0.005145
# Mann–Whitney U p = 0.000006
# Cohen's d = 1.086
# Cliff's delta = 0.889 (large)
#
#
# ============================================================
# Operation: get_item_price
# ============================================================
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run
# unoptimized: 0.311 mJ (95% CI [0.308, 0.313])
# optimized:   0.220 mJ (95% CI [0.217, 0.222])
# Welch t-test p = 9.61e-36
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 20.426
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run — Package
# unoptimized: 0.287 mJ (95% CI [0.284, 0.289])
# optimized:   0.203 mJ (95% CI [0.201, 0.205])
# Welch t-test p = 1.36e-35
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 20.156
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run — DRAM
# unoptimized: 0.024 mJ (95% CI [0.024, 0.024])
# optimized:   0.017 mJ (95% CI [0.017, 0.017])
# Welch t-test p = 3.94e-31
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 14.658
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net)
# unoptimized: 4.328 mJ (95% CI [3.892, 4.764])
# optimized:   11.424 mJ (95% CI [10.359, 12.490])
# Welch t-test p = 5.85e-12
# Mann–Whitney U p = 3.23e-07
# Cohen's d = -4.462
# Cliff's delta = -1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net) — Package
# unoptimized: 3.293 mJ (95% CI [2.940, 3.647])
# optimized:   10.339 mJ (95% CI [9.636, 11.042])
# Welch t-test p = 2.36e-16
# Mann–Whitney U p = 3.23e-07
# Cohen's d = -6.483
# Cliff's delta = -1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net) — DRAM
# unoptimized: 0.980 mJ (95% CI [0.769, 1.192])
# optimized:   0.961 mJ (95% CI [0.682, 1.241])
# Welch t-test p = 0.910175
# Mann–Whitney U p = 0.669291
# Cohen's d = 0.039
# Cliff's delta = 0.086 (negligible)
#
#
# ============================================================
# Operation: item_defaults
# ============================================================
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run
# unoptimized: 0.244 mJ (95% CI [0.242, 0.246])
# optimized:   0.205 mJ (95% CI [0.203, 0.207])
# Welch t-test p = 3.99e-27
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 11.298
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run — Package
# unoptimized: 0.224 mJ (95% CI [0.222, 0.226])
# optimized:   0.188 mJ (95% CI [0.187, 0.190])
# Welch t-test p = 5.69e-26
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 10.544
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run — DRAM
# unoptimized: 0.018 mJ (95% CI [0.018, 0.019])
# optimized:   0.015 mJ (95% CI [0.015, 0.015])
# Welch t-test p = 3.95e-25
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 9.648
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net)
# unoptimized: 1.781 mJ (95% CI [1.681, 1.881])
# optimized:   0.192 mJ (95% CI [0.115, 0.269])
# Welch t-test p = 1.48e-23
# Mann–Whitney U p = 2.17e-07
# Cohen's d = 9.003
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net) — Package
# unoptimized: 2.110 mJ (95% CI [2.009, 2.211])
# optimized:   0.408 mJ (95% CI [0.342, 0.475])
# Welch t-test p = 1.84e-23
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 10.164
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net) — DRAM
# unoptimized: 0.111 mJ (95% CI [0.080, 0.143])
# optimized:   0.017 mJ (95% CI [0.003, 0.031])
# Welch t-test p = 0.000006
# Mann–Whitney U p = 0.000003
# Cohen's d = 1.972
# Cliff's delta = 0.883 (large)
#
#
# ============================================================
# Operation: get_buying_amount
# ============================================================
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run
# unoptimized: 11.161 mJ (95% CI [11.141, 11.181])
# optimized:   10.221 mJ (95% CI [10.189, 10.253])
# Welch t-test p = 6.04e-30
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 18.001
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run — Package
# unoptimized: 10.291 mJ (95% CI [10.272, 10.310])
# optimized:   9.440 mJ (95% CI [9.409, 9.471])
# Welch t-test p = 6.53e-29
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 16.970
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run — DRAM
# unoptimized: 0.861 mJ (95% CI [0.859, 0.863])
# optimized:   0.799 mJ (95% CI [0.796, 0.802])
# Welch t-test p = 1.70e-25
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 12.370
# Cliff's delta = 1.000 (large)
# System energy per run (net)
# unoptimized: 68.413 mJ (95% CI [63.482, 73.343])
# optimized:   43.369 mJ (95% CI [40.268, 46.470])
# Welch t-test p = 6.45e-10
# Mann–Whitney U p = 3.81e-07
# Cohen's d = 3.111
# Cliff's delta = 0.994 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net) — Package
# unoptimized: 53.563 mJ (95% CI [49.778, 57.348])
# optimized:   26.999 mJ (95% CI [24.879, 29.119])
# Welch t-test p = 5.32e-13
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 4.431
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net) — DRAM
# unoptimized: 15.391 mJ (95% CI [13.844, 16.938])
# optimized:   19.038 mJ (95% CI [17.669, 20.407])
# Welch t-test p = 0.000718
# Mann–Whitney U p = 0.001644
# Cohen's d = -1.278
# Cliff's delta = -0.617 (large)
#
#
# ============================================================
# Operation: timeline
# ============================================================
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run
# unoptimized: 182.061 mJ (95% CI [180.752, 183.371])
# optimized:   8.544 mJ (95% CI [8.405, 8.683])
# Welch t-test p = 3.70e-33
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 95.342
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run — Package
# unoptimized: 168.595 mJ (95% CI [167.410, 169.779])
# optimized:   7.906 mJ (95% CI [7.780, 8.032])
# Welch t-test p = 2.47e-33
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 97.587
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# Process energy per run — DRAM
# unoptimized: 13.437 mJ (95% CI [13.324, 13.550])
# optimized:   0.632 mJ (95% CI [0.621, 0.643])
# Welch t-test p = 6.27e-32
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 81.925
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net)
# unoptimized: 3293.567 mJ (95% CI [3271.285, 3315.849])
# optimized:   134.255 mJ (95% CI [129.119, 139.391])
# Welch t-test p = 7.91e-36
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 99.984
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net) — Package
# unoptimized: 3136.942 mJ (95% CI [3117.574, 3156.310])
# optimized:   129.290 mJ (95% CI [124.637, 133.942])
# Welch t-test p = 8.27e-37
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 109.267
# Cliff's delta = 1.000 (large)
# /var/folders/xh/kj8mjqr14z70q579rsg11v2r0000gn/T/ipykernel_11715/270246501.py:126: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([x, y], labels=[v_unopt, v_opt], widths=0.6)
# System energy per run (net) — DRAM
# unoptimized: 156.306 mJ (95% CI [146.102, 166.510])
# optimized:   4.737 mJ (95% CI [3.845, 5.628])
# Welch t-test p = 1.25e-16
# Mann–Whitney U p = 3.23e-07
# Cohen's d = 10.709
# Cliff's delta = 1.000 (large)
